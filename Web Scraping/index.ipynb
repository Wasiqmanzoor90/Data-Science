# %%
pip install requests, beautifulsoup4
# Out:
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.3 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ERROR: Invalid requirement: 'requests,': Expected end or semicolon (after name and no valid version specifier)
#     requests,
#             ^

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
base_url = 'http://books.toscrape.com/catalogue/page-{}.html'
data=[]

# %%
for page in range(1,6):
    url = base_url.format(page)
    soup = BeautifulSoup(requests.get(url).text,'html.parser')
    
    book = soup.select("article.product_pod")
    for b in book:
        title = b.h3.a['title']
        price= b.select_one(".price_color").text
        availability= b .select_one('.availability').text.strip()
        rating = b.p["class"][1]
        link = 'http://books.toscrape.com/catalogue'+b.h3.a['href']
        
        data.append({
            "Title": title,
            "Price": price,
            "Availabity": availability,
            "Links" : link
        })

# %%
df = pd.DataFrame(data)
df.to_csv("books.csv", index=False)

# %%
df.head()
# Out:
#                                    Title    Price Availabity  \
# 0                   A Light in the Attic  Â£51.77   In stock
# 1                     Tipping the Velvet  Â£53.74   In stock
# 2                             Soumission  Â£50.10   In stock
# 3                          Sharp Objects  Â£47.82   In stock
# 4  Sapiens: A Brief History of Humankind  Â£54.23   In stock
#
#                                                Links
# 0  http://books.toscrape.com/cataloguea-light-in-...
# 1  http://books.toscrape.com/cataloguetipping-the...
# 2  http://books.toscrape.com/cataloguesoumission_...
# 3  http://books.toscrape.com/cataloguesharp-objec...
# 4  http://books.toscrape.com/cataloguesapiens-a-b...

# %%
df.shape
# Out:
# (100, 4)
