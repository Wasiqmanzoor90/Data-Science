# %%
import pandas as pd

# %%
data = pd.read_csv(r'C:\Users\Dell\Documents\Project\Dataset\netflix_titles.csv')

# %%
data.head()
# Out:
#     show_id     type                                    title  \
# 0  81145628    Movie  Norm of the North: King Sized Adventure
# 1  80117401    Movie               Jandino: Whatever it Takes
# 2  70234439  TV Show                       Transformers Prime
# 3  80058654  TV Show         Transformers: Robots in Disguise
# 4  80125979    Movie                             #realityhigh
#
#                    director  \
# 0  Richard Finn, Tim Maltby
# 1                       NaN
# 2                       NaN
# 3                       NaN
# 4          Fernando Lebrija
#
#                                                 cast  \
# 0  Alan Marriott, Andrew Toth, Brian Dobson, Cole...
# 1                                   Jandino Asporaat
# 2  Peter Cullen, Sumalee Montano, Frank Welker, J...
# 3  Will Friedle, Darren Criss, Constance Zimmer, ...
# 4  Nesta Cooper, Kate Walsh, John Michael Higgins...
#
#                                     country         date_added  release_year  \
# ...

# %%
data.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 6234 entries, 0 to 6233
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       6234 non-null   int64
#  1   type          6234 non-null   str
#  2   title         6234 non-null   str
#  3   director      4265 non-null   str
#  4   cast          5664 non-null   str
#  5   country       5758 non-null   str
#  6   date_added    6223 non-null   str
#  7   release_year  6234 non-null   int64
#  8   rating        6224 non-null   str
#  9   duration      6234 non-null   str
#  10  listed_in     6234 non-null   str
#  11  description   6234 non-null   str
# dtypes: int64(2), str(10)
# memory usage: 584.6 KB

# %%
data['type'].value_counts()
# Out:
# type
# Movie      4265
# TV Show    1969
# Name: count, dtype: int64

# %%
data[data['release_year']==2020]
# Out:
#        show_id     type                                              title  \
# 1315  81034946  TV Show                                 Maradona in Mexico
# 3180  81214114    Movie                                      Bulletproof 2
# 3189  81039393  TV Show                                              Cheer
# 3195  80233408    Movie                              Live Twice, Love Once
# 3220  80997687  TV Show                                            Dracula
# 3221  80237347  TV Show                                Go! Go! Cory Carson
# 3249  81006825    Movie                      All the Freckles in the World
# 3325  81160763  TV Show                                     Sex, Explained
# 3352  81127902    Movie                                  A Fall from Grace
# 3353  80995039  TV Show                                               Ares
# 3354  81062580  TV Show                                 Nailed It! Germany
# ...

# %%
data['country'].nunique()
# Out:
# 554

# %%
data['country'].isnull().sum()
# Out:
# np.int64(0)

# %% [markdown]
# **Here we fill null values with unknown value**

# %%
data['country'] = data['country'].fillna('Unknown')

# %% [markdown]
# **Now here we are checking that all null values in coutry get replaced by unknow**

# %%
data[data['country'].str.contains('Unknown')]
# Out:
#        show_id     type                                           title  \
# 10    80169755    Movie                     Joaquín Reyes: Una y no más
# 12    80182480    Movie                        Krish Trish and Baltiboy
# 13    80182483    Movie        Krish Trish and Baltiboy: Battle of Wits
# 14    80182596    Movie  Krish Trish and Baltiboy: Best Friends Forever
# 15    80182482    Movie       Krish Trish and Baltiboy: Comics of India
# ...        ...      ...                                             ...
# 6170  80136456  TV Show                                    Age of Glory
# 6195  80136790  TV Show                                  Goodnight DJ 1
# 6199  80244228  TV Show                          Beauty and the Bitches
# 6228  80159925  TV Show                                        Kikoriki
# 6231  80116008    Movie          Little Baby Bum: Nursery Rhyme Friends
#
#                          director  \
# 10          José Miguel Contreras
# ...

# %% [markdown]
# **There are many actors in cast so we have to get only first actore so we are seprating by , and str[0] menas which here 0 means ist coma and in last we take all first actors and keep it in first column that we have created**

# %%
data['First_actor'] = data['cast'].str.split(',').str[0]

# %%
data.head()
# Out:
#     show_id     type                                    title  \
# 0  81145628    Movie  Norm of the North: King Sized Adventure
# 1  80117401    Movie               Jandino: Whatever it Takes
# 2  70234439  TV Show                       Transformers Prime
# 3  80058654  TV Show         Transformers: Robots in Disguise
# 4  80125979    Movie                             #realityhigh
#
#                    director  \
# 0  Richard Finn, Tim Maltby
# 1                       NaN
# 2                       NaN
# 3                       NaN
# 4          Fernando Lebrija
#
#                                                 cast  \
# 0  Alan Marriott, Andrew Toth, Brian Dobson, Cole...
# 1                                   Jandino Asporaat
# 2  Peter Cullen, Sumalee Montano, Frank Welker, J...
# 3  Will Friedle, Darren Criss, Constance Zimmer, ...
# 4  Nesta Cooper, Kate Walsh, John Michael Higgins...
#
#                                     country         date_added  release_year  \
# ...

# %% [markdown]
# **oldest movies in this dataset**

# %%
data['release_year'].min()
# Out:
# np.int64(1925)

# %%
data['release_year'].max()
# Out:
# np.int64(2020)

# %%
data['type'].value_counts()
# Out:
# type
# Movie      4265
# TV Show    1969
# Name: count, dtype: int64

# %% [markdown]
# **Here we filter tv shows that have een realsed in 2020**

# %%
data[(data['release_year']==2020)&
     (data['type']=='TV Show')
     ]
# Out:
#        show_id     type                                              title  \
# 1315  81034946  TV Show                                 Maradona in Mexico
# 3189  81039393  TV Show                                              Cheer
# 3220  80997687  TV Show                                            Dracula
# 3221  80237347  TV Show                                Go! Go! Cory Carson
# 3325  81160763  TV Show                                     Sex, Explained
# 3353  80995039  TV Show                                               Ares
# 3354  81062580  TV Show                                 Nailed It! Germany
# 3363  80996973  TV Show                                  Handsome Siblings
# 3379  81062828  TV Show         Killer Inside: The Mind of Aaron Hernandez
# 3426  80221553  TV Show                   Kipo and the Age of Wonderbeasts
# 3436  80239306  TV Show                         The Healing Powers of Dude
# ...

# %%
data[
    (data['country']=='United States')&
    (data['type']=='TV Show')
]
# Out:
#        show_id     type                             title director  \
# 2     70234439  TV Show                Transformers Prime      NaN
# 3     80058654  TV Show  Transformers: Robots in Disguise      NaN
# 8     80117902  TV Show                      Fire Chasers      NaN
# 54    80113482  TV Show                       No Tomorrow      NaN
# 61    80113641  TV Show                         Frequency      NaN
# ...        ...      ...                               ...      ...
# 6225  70153412  TV Show                           Frasier      NaN
# 6226  70243132  TV Show               La Familia P. Luche      NaN
# 6229  80000063  TV Show                      Red vs. Blue      NaN
# 6230  70286564  TV Show                             Maron      NaN
# 6233  70153404  TV Show                           Friends      NaN
#
#                                                    cast        country  \
# 2     Peter Cullen, Sumalee Montano, Frank Welker, J...  United States
# ...

# %% [markdown]
# **Here we get the number of movies that have been realsed each year**

# %%
data.groupby('release_year')['title'].count()
# Out:
# release_year
# 1925       1
# 1942       2
# 1943       3
# 1944       3
# 1945       3
#         ...
# 2016     830
# 2017     959
# 2018    1063
# 2019     843
# 2020      25
# Name: title, Length: 72, dtype: int64

# %%
data[data['title'].str.contains('Love')]
# Out:
#        show_id     type                                             title  \
# 19    80057969    Movie                                              Love
# 46    81016044    Movie                      Bangkok Traffic (Love) Story
# 47    80158838    Movie                   I Fine... Thank You... Love You
# 66    81011682  TV Show  Christiane Amanpour: Sex & Love Around the World
# 74    80184358  TV Show                                          Lovesick
# ...        ...      ...                                               ...
# 5848  80174280  TV Show                  Ainori Love Wagon: Asian Journey
# 5896  80993774  TV Show                                Roonpi Secret Love
# 5941  81026700  TV Show                               My First First Love
# 6026  80041601  TV Show                                          Lovesick
# 6048  80126684  TV Show                                   Love Me As I Am
#
#                   director                                               cast  \
# ...

# %%
data[data['director'].str.contains('Gaspar Noé')]
# Out:
#      show_id   type title    director  \
# 19  80057969  Movie  Love  Gaspar Noé
#
#                                                  cast          country  \
# 19  Karl Glusman, Klara Kristin, Aomi Muyock, Ugo ...  France, Belgium
#
#            date_added  release_year rating duration  \
# 19  September 8, 2017          2015     NR  135 min
#
#                                   listed_in  \
# 19  Cult Movies, Dramas, Independent Movies
#
#                                           description
# 19  A man in an unsatisfying marriage recalls the ...

# %% [markdown]
# **so here we convert textual date into real date and str.strip mean that cut spaces dont keep any space between date**

# %%
data['date_added'] = pd.to_datetime(data['date_added'].str.strip())

# %%
data.head()
# Out:
#     show_id     type                                    title  \
# 0  81145628    Movie  Norm of the North: King Sized Adventure
# 1  80117401    Movie               Jandino: Whatever it Takes
# 2  70234439  TV Show                       Transformers Prime
# 3  80058654  TV Show         Transformers: Robots in Disguise
# 4  80125979    Movie                             #realityhigh
#
#                    director  \
# 0  Richard Finn, Tim Maltby
# 1                       NaN
# 2                       NaN
# 3                       NaN
# 4          Fernando Lebrija
#
#                                                 cast  \
# 0  Alan Marriott, Andrew Toth, Brian Dobson, Cole...
# 1                                   Jandino Asporaat
# 2  Peter Cullen, Sumalee Montano, Frank Welker, J...
# 3  Will Friedle, Darren Criss, Constance Zimmer, ...
# 4  Nesta Cooper, Kate Walsh, John Michael Higgins...
#
#                                     country date_added  release_year  \
# ...
