# %%
# %pip install pandas

# %%
import pandas as pd

# %% [markdown]
# wes mckeny was the founder of pandas or we can he created it for manipulation of data and cleaning of data
# so in pandas here are two tyes of data structure
# 1. Series
# 2. Dataframe

# %% [markdown]
# Series Deals with 1 D array

# %%
dt =[20,45,78,90]  

dp = pd.Series(dt)
print(dp.ndim)
print(dp)

# %% [markdown]
# Data Frame deal with 2D array  or we can say rows and columns

# %%
dc = {
    "name":['wasiq','umer','ubaid'],
    "age":[12,19,21],
    "Roll-no":[1,2,3]
}

# %%
df = pd.DataFrame(dc)
print(df)

# %%
data = pd.read_csv(r'C:\Users\Dell\Documents\Project\Dataset\titanic.csv')  #here its gets read through read_csv function

# %% [markdown]
# Head gives first five rows by default

# %%
data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# tail give last 5 rows by default

# %%
data.tail()

# %% [markdown]
# Here info tells use basic information about our dataset

# %%
data.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    str
#  4   Sex          891 non-null    str
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    str
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    str
#  11  Embarked     889 non-null    str
# dtypes: float64(2), int64(5), str(5)
# memory usage: 83.7 KB

# %% [markdown]
# Here shape tells how many rows and columns are there

# %%
data.shape
# Out:
# (891, 12)

# %% [markdown]
# Here it tells how many rows have null values and sum make sure to give sum of all null values

# %%
data.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %% [markdown]
# Here it tells how many rows have values and sum make sure to give sum of all not null values

# %%
data.notnull().sum()
# Out:
# PassengerId    891
# Survived       891
# Pclass         891
# Name           891
# Sex            891
# Age            714
# SibSp          891
# Parch          891
# Ticket         891
# Fare           891
# Cabin          204
# Embarked       889
# dtype: int64

# %%
data['Age'].isnull().sum()
# Out:
# np.int64(177)

# %%
data1 = data[['Age','Name']]

# %%
data1

# %% [markdown]
# Loc deal with Names

# %%
data.loc[:,'Name']

# %%
data.head()

# %% [markdown]
# Loc deals with name to choose a particular columns or rows but if we want a particular value we have to give index as well in loc

# %%
data.loc[0,'Name']
# Out:
# 'Braund, Mr. Owen Harris'

# %% [markdown]
# Iloc deal with numbers, its basically 2d arrey

# %%
data.iloc[0,3]
# Out:
# 'Braund, Mr. Owen Harris'

# %% [markdown]
# **Filter and sorting**

# %%
data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# **Here we sort by fare and keeping ascending false**

# %%
data.sort_values(by='Fare' ,ascending=False)
# Out:
#      PassengerId  Survived  Pclass                                Name  \
# 679          680         1       1  Cardeza, Mr. Thomas Drake Martinez
# 258          259         1       1                    Ward, Miss. Anna
# 737          738         1       1              Lesurer, Mr. Gustave J
# 88            89         1       1          Fortune, Miss. Mabel Helen
# 438          439         0       1                   Fortune, Mr. Mark
# ..           ...       ...     ...                                 ...
# 806          807         0       1              Andrews, Mr. Thomas Jr
# 815          816         0       1                    Fry, Mr. Richard
# 466          467         0       2               Campbell, Mr. William
# 481          482         0       2    Frost, Mr. Anthony Wood "Archie"
# 822          823         0       1     Reuchlin, Jonkheer. John George
#
#         Sex   Age  SibSp  Parch    Ticket      Fare        Cabin Embarked
# ...

# %% [markdown]
# **Here we got the value count of gender male and female or we can say we get the total number male and femal in dataset**

# %%
data['Sex'].value_counts()
# Out:
# Sex
# male      577
# female    314
# Name: count, dtype: int64

# %% [markdown]
# **Here we get total number alive and dead people**

# %%
data['Survived'].value_counts()
# Out:
# Survived
# 0    549
# 1    342
# Name: count, dtype: int64

# %% [markdown]
# **Here we got only that people that have survide or we can sat that are alive**

# %%
survived_data = data[data['Survived']=='Alive']
survived_data.head()
# Out:
#    PassengerId Survived  Pclass                            Name   Sex   Age  \
# 0            1    Alive       3         Braund, Mr. Owen Harris  male  22.0
# 4            5    Alive       3        Allen, Mr. William Henry  male  35.0
# 5            6    Alive       3                Moran, Mr. James  male   NaN
# 6            7    Alive       1         McCarthy, Mr. Timothy J  male  54.0
# 7            8    Alive       3  Palsson, Master. Gosta Leonard  male   2.0
#
#    SibSp  Parch     Ticket     Fare Cabin Embarked
# 0      1      0  A/5 21171   7.2500   NaN        S
# 4      0      0     373450   8.0500   NaN        S
# 5      0      0     330877   8.4583   NaN        Q
# 6      0      0      17463  51.8625   E46        S
# 7      3      1     349909  21.0750   NaN        S

# %% [markdown]
# Here we we give 0 value Alive and 1 Dead it simply converts

# %%
data['Survived']= data['Survived'].map({0:'Alive',1:'Dead'})

# %%
data.head()
# Out:
#    PassengerId Survived  Pclass  \
# 0            1    Alive       3
# 1            2     Dead       1
# 2            3     Dead       3
# 3            4     Dead       1
# 4            5    Alive       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
data.shape
# Out:
# (891, 12)

# %% [markdown]
# **drop the rows in age column that have null value**

# %%
data.dropna(subset=['Age'],inplace=True)

# %%
data.shape
# Out:
# (714, 12)

# %% [markdown]
# **Filter out only that value that have age greater than 30**

# %%
data[data['Age']>30]
# Out:
#      PassengerId Survived  Pclass  \
# 1              2     Dead       1
# 3              4     Dead       1
# 4              5    Alive       3
# 6              7    Alive       1
# 11            12     Dead       1
# ..           ...      ...     ...
# 873          874    Alive       3
# 879          880     Dead       1
# 881          882    Alive       3
# 885          886    Alive       3
# 890          891    Alive       3
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# **here we filter data with multiple conditions**

# %%
data[(data['Age']>30)&
     (data['Sex']=='male')&
     (data['Survived']=='Alive')
     ]
# Out:
#      PassengerId Survived  Pclass                                  Name   Sex  \
# 4              5    Alive       3              Allen, Mr. William Henry  male
# 6              7    Alive       1               McCarthy, Mr. Timothy J  male
# 13            14    Alive       3           Andersson, Mr. Anders Johan  male
# 20            21    Alive       2                  Fynney, Mr. Joseph J  male
# 30            31    Alive       1              Uruchurtu, Don. Manuel E  male
# ..           ...      ...     ...                                   ...   ...
# 867          868    Alive       1  Roebling, Mr. Washington Augustus II  male
# 872          873    Alive       1              Carlsson, Mr. Frans Olof  male
# 873          874    Alive       3           Vander Cruyssen, Mr. Victor  male
# 881          882    Alive       3                    Markun, Mr. Johann  male
# 890          891    Alive       3                   Dooley, Mr. Patrick  male
#
# ...

# %%
data['Age'].isnull().sum()
# Out:
# np.int64(0)

# %% [markdown]
# **Here we fill null values in age column with with average age**

# %%
data['Age']= data['Age'].fillna(data['Age'].mean())

# %%
data['Age'].isnull().sum()
# Out:
# np.int64(0)

# %%
data.head()
# Out:
#    PassengerId Survived  Pclass  \
# 0            1    Alive       3
# 1            2     Dead       1
# 2            3     Dead       3
# 3            4     Dead       1
# 4            5    Alive       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
data.sort_values(by='Age')
# Out:
#      PassengerId Survived  Pclass                                  Name  \
# 803          804     Dead       3       Thomas, Master. Assad Alexander
# 755          756     Dead       2             Hamalainen, Master. Viljo
# 644          645     Dead       3                Baclini, Miss. Eugenie
# 469          470     Dead       3         Baclini, Miss. Helene Barbara
# 78            79     Dead       2         Caldwell, Master. Alden Gates
# ..           ...      ...     ...                                   ...
# 116          117    Alive       3                  Connors, Mr. Patrick
# 493          494    Alive       1               Artagaveytia, Mr. Ramon
# 96            97    Alive       1             Goldschmidt, Mr. George B
# 851          852    Alive       3                   Svensson, Mr. Johan
# 630          631     Dead       1  Barkworth, Mr. Algernon Henry Wilson
#
#         Sex    Age  SibSp  Parch    Ticket     Fare Cabin Embarked
# ...

# %%
data.sort_values(by=['Age','Fare'])
# Out:
#      PassengerId Survived  Pclass                                  Name  \
# 803          804     Dead       3       Thomas, Master. Assad Alexander
# 755          756     Dead       2             Hamalainen, Master. Viljo
# 469          470     Dead       3         Baclini, Miss. Helene Barbara
# 644          645     Dead       3                Baclini, Miss. Eugenie
# 831          832     Dead       2       Richards, Master. George Sibley
# ..           ...      ...     ...                                   ...
# 116          117    Alive       3                  Connors, Mr. Patrick
# 96            97    Alive       1             Goldschmidt, Mr. George B
# 493          494    Alive       1               Artagaveytia, Mr. Ramon
# 851          852    Alive       3                   Svensson, Mr. Johan
# 630          631     Dead       1  Barkworth, Mr. Algernon Henry Wilson
#
#         Sex    Age  SibSp  Parch    Ticket     Fare Cabin Embarked
# ...

# %% [markdown]
# **It filters the paricular column**

# %%
data[data['Survived'].isin(['Alive'])]
# Out:
#      PassengerId Survived  Pclass                                  Name  \
# 0              1    Alive       3               Braund, Mr. Owen Harris
# 4              5    Alive       3              Allen, Mr. William Henry
# 6              7    Alive       1               McCarthy, Mr. Timothy J
# 7              8    Alive       3        Palsson, Master. Gosta Leonard
# 12            13    Alive       3        Saundercock, Mr. William Henry
# ..           ...      ...     ...                                   ...
# 883          884    Alive       2         Banfield, Mr. Frederick James
# 884          885    Alive       3                Sutehall, Mr. Henry Jr
# 885          886    Alive       3  Rice, Mrs. William (Margaret Norton)
# 886          887    Alive       2                 Montvila, Rev. Juozas
# 890          891    Alive       3                   Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# ...

# %% [markdown]
# **It gives us a particular row on basis Name**

# %%
data[data['Name'].str.contains('John Bradley')]
# Out:
#    PassengerId Survived  Pclass  \
# 1            2     Dead       1
#
#                                                 Name     Sex   Age  SibSp  \
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
#
#    Parch    Ticket     Fare Cabin Embarked
# 1      0  PC 17599  71.2833   C85        C

# %% [markdown]
# **Here we do filteration and sorting togather**

# %%
data[data['Age']>30].sort_values(by="Age")
# Out:
#      PassengerId Survived  Pclass  \
# 767          768    Alive       3
# 814          815    Alive       3
# 801          802     Dead       2
# 805          806    Alive       3
# 817          818    Alive       2
# ..           ...      ...     ...
# 116          117    Alive       3
# 493          494    Alive       1
# 96            97    Alive       1
# 851          852    Alive       3
# 630          631     Dead       1
#
#                                             Name     Sex   Age  SibSp  Parch  \
# 767                           Mangan, Miss. Mary  female  30.5      0      0
# 814                   Tomlin, Mr. Ernest Portage    male  30.5      0      0
# 801  Collyer, Mrs. Harvey (Charlotte Annie Tate)  female  31.0      1      1
# 805                    Johansson, Mr. Karl Johan    male  31.0      0      0
# 817                           Mallet, Mr. Albert    male  31.0      1      1
# ..                                           ...     ...   ...    ...    ...
# ...

# %%
data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
data.loc[0,'Name']
# Out:
# 'Braund, Mr. Owen Harris'

# %%
data.iloc[0,3]
# Out:
# 'Braund, Mr. Owen Harris'

# %%
data.iloc[0,3] = 'sahil'

# %%
data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                                              sahil    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
data.iloc[1,3]
# Out:
# 'Cumings, Mrs. John Bradley (Florence Briggs Thayer)'

# %%
data.replace('Cumings, Mrs. John Bradley (Florence Briggs Thayer)','Moonis')
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                                           sahil    male  22.0      1      0
# 1                                          Moonis  female  38.0      1      0
# 2                          Heikkinen, Miss. Laina  female  26.0      0      0
# 3    Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1      0
# 4                        Allen, Mr. William Henry    male  35.0      0      0
# ...

# %%
data.set_index('PassengerId',inplace=True)

# %%
data.rename(columns={'Sex':'Gender'},inplace=True)

# %%
data.iloc[0,2]
# Out:
# 'sahil'

# %%
data.sort_values(by='Age')

# %%
data['Sex'].value_counts()
# Out:
# Sex
# male      453
# female    261
# Name: count, dtype: int64

# %%
data['Fare'].sum()
# Out:
# np.float64(24771.883)

# %%
data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
data['Survived'].value_counts()
# Out:
# Survived
# 0    549
# 1    342
# Name: count, dtype: int64

# %% [markdown]
# **Split data into groups**

# %%
data.groupby('Sex')['Survived'].sum()
# Out:
# Sex
# female    233
# male      109
# Name: Survived, dtype: int64

# %%
data.groupby('Pclass')['Survived'].sum()
# Out:
# Pclass
# 1    136
# 2     87
# 3    119
# Name: Survived, dtype: int64

# %%
data.groupby('Sex')['Fare'].mean()
# Out:
# Sex
# female    44.479818
# male      25.523893
# Name: Fare, dtype: float64

# %%
children = data[data['Age']<18]

# %%
children.shape
# Out:
# (113, 12)

# %%
alive_children = (children[children['Survived']==1])

# %%
alive_children.shape
# Out:
# (61, 12)

# %%
data.head()
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 890          891         0       3                       Dooley, Mr. Patrick
# 889          890         1       1                     Behr, Mr. Karl Howell
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 887          888         1       1              Graham, Miss. Margaret Edith
# 886          887         0       2                     Montvila, Rev. Juozas
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 890    male  32.0      0      0      370376   7.75   NaN        Q
# 889    male  26.0      0      0      111369  30.00  C148        C
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 886    male  27.0      0      0      211536  13.00   NaN        S

# %%
data.sort_index(ascending=False,inplace=True)

# %%
data['Pclass'].value_counts()
# Out:
# Pclass
# 3    491
# 1    216
# 2    184
# Name: count, dtype: int64

# %%
data.groupby(['Pclass','Sex'])['Survived'].sum()
# Out:
# Pclass  Sex
# 1       female    91
#         male      45
# 2       female    70
#         male      17
# 3       female    72
#         male      47
# Name: Survived, dtype: int64
