# %%
from sklearn.cluster import KMeans

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv(r"C:\Users\Dell\Documents\Project\Dataset\Iris.csv")

# %%
data.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
#sum od square error
sse=[]
k_range = range(1,11)
for k in k_range:
    km = KMeans(n_clusters=k)
    km.fit(data[['SepalLengthCm','SepalWidthCm']])
    sse.append(km.inertia_)
plt.plot(k_range,sse,marker='o')

# %%
from sklearn.cluster import AgglomerativeClustering
agg = AgglomerativeClustering(n_clusters=3)
agg.fit(data[['SepalLengthCm','SepalWidthCm']])
plt.scatter(data['SepalLengthCm'],data['SepalWidthCm'],c=agg.labels_)

# %%
df1 = data.iloc[:,[1,2]].values

# %%
import scipy.cluster.hierarchy as sch
dend = sch.dendrogram(sch.linkage(df1,method='ward'))
plt.title("Dendogram")
# Out:
# Text(0.5, 1.0, 'Dendogram')
