# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv(r'C:\Users\Dell\Downloads\iris.csv')

# %%
data.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %% [markdown]
# If i Know X , what will be the expected Y
# for eg
#
# if sepal length = 6 cm the line tell apporiate Sepal width

# %%
sns.regplot(x='SepalLengthCm', y='PetalLengthCm', data=data)
plt.xlabel('Sepal Length(Independent Variable)')
plt.ylabel('Petal Length(Dependent Variable)')
plt.title('Scatter Plot of Sepal Length vs Petal Length')
plt.show()
