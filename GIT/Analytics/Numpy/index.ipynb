# %%
pip install numpy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.3 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# Numerical Python also known as Numpy it have functionality called numpy arrat which is basically like python list but it's 50x fater than python list. it was created in 2005 by developer called travis oliphant, it's deep down written in c++ language

# %%
#here we import numpy
import numpy as np

# %% [markdown]
# **her we do slicing and indexeing in numpy array**

# %%
ar1 = np.array([12,54,78,90,1])
print(ar1[1])
print(type(ar1))
print(ar1[-1])
print(ar1[1:4])
# Out:
# 54
# <class 'numpy.ndarray'>
# 1
# [54 78 90]

# %% [markdown]
# 1D Array

# %%
arr = np.array([11,22,33])
print(arr)
# Out:
# [11 22 33]

# %% [markdown]
# 2D array

# %%
arr2 = np.array([[22,32,43],[41,56,87],[44,5,7]])
# print(arr2[0][2])
# print(arr2[2][1])
# print(arr2.ndim)
print(arr2)
# Out:
# [[22 32 43]
#  [41 56 87]
#  [44  5  7]]

# %% [markdown]
# **Stastical operation**

# %%
arr9 = np.array([23,11,9,21,32,8,7])
# np.mean(arr9)  #average value
# np.sum(arr9)  #here it sum
# np.max(arr9)  #here we get maximum value
# np.min(arr9)  #here we get minimum value
# Out:
# np.int64(7)

# %% [markdown]
# **Mathematical operations**

# %%
a = np.array([21,11,4])
b = np.array([20,10,6])

# %%
np.add(a,b)
# Out:
# array([41, 21, 10])

# %%
np.subtract(a,b)
# Out:
# array([ 1,  1, -2])

# %%
np.multiply(a,b)
# Out:
# array([420, 110,  24])

# %%
np.divide(a,b)
# Out:
# array([1.05      , 1.1       , 0.66666667])

# %%
a = np.array([25,4,2,64])

# %%
np.power(a,2)
# Out:
# array([ 625,   16,    4, 4096])

# %%
np.power(a,3)
# Out:
# array([ 15625,     64,      8, 262144])

# %%
np.sqrt(a)
# Out:
# array([5.        , 2.        , 1.41421356, 8.        ])

# %% [markdown]
# **Random number gives randomly some number**

# %%
x = np.random.rand()
print(x)
# Out:
# 0.6259198859298967

# %%
x= np.random.rand(3)
print(x)
# Out:
# [0.7718719  0.3569604  0.52640912]

# %% [markdown]
# **Here we are giving range from where to start and where to end**

# %%
y= np.random.randint(1,20,size=4)
print(y)
# Out:
# [12  6  9  7]

# %%
y= np.random.randint(1000,9999,size=3)  #here we generate random 4 digit number
print(y)
# Out:
# [8302 6263 8810 6856 1532 1554 2156 9732 3234 2461]

# %%
z = np.random.randint(100000,999999,size=2) #here we genrate random 6 digit number 
print(z)
# Out:
# [240603 782264]

# %%
y1 = np.random.randn(2)
print(y1)
# Out:
# [-0.72328235  1.18311488]

# %% [markdown]
# **Array Manipulation**

# %%
a1 = np.array([1,2,3,4])
arr = np.append(a1,[5,6,7,8])
print(arr)
# Out:
# [1 2 3 4 5 6 7 8]

# %%
a2 = np.array([[10,20,30],[40,50,60]])
arr2 = np.append(a2,[[70,80,90]],axis=0)  #here 0 means row and 1 means column
print(arr2)
# Out:
# [[10 20 30]
#  [40 50 60]
#  [70 80 90]]

# %%
arr2[1,0]=38
arr2[1,2] = 62
arr2[2,1]=87
arr2[0,2]=56
arr2[0,1]=21
print(arr2)
# Out:
# [[10 21 56]
#  [38 50 62]
#  [70 87 90]]

# %%
a3 = np.delete(arr2,1,axis=1)
print(a3)
# Out:
# [[10 56]
#  [38 62]
#  [70 90]]

# %% [markdown]
# **Seraching and sorting**

# %%
arr = np.array([23,2,1,8,11])
a1 = np.sort(arr)
print(a1)
# Out:
# [ 1  2  8 11 23]

# %%
d2 = np.array([[23,2,1],[8,11,4]])
d3 = np.sort(d2,axis=0)
print(d3)
# Out:
# [[ 8  2  1]
#  [23 11  4]]

# %%
ard = np.array([30,40,50,40])
np.where(ard==40)
# Out:
# (array([1, 3]),)

# %%
d5 = np.array([1,2,4,5,7])
np.searchsorted(d5,6)
# Out:
# np.int64(4)

# %% [markdown]
# **Reshape and resize**

# %%
#convertig 2d into 1d
f6 = np.array([[30,40],[50,60]])
a4 = f6.flatten()
print(a4)
# Out:
# [30 40 50 60]

# %%
f7 = np.array([20,30,40,50,60,70])
a9 = f7.reshape(3,2)
print(a9)
# Out:
# [[20 30]
#  [40 50]
#  [60 70]]
