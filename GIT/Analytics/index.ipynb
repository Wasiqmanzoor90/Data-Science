# %%
pip install numpy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.3 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# Numerical Python also known as Numpy it have functionality called numpy arrat which is basically like python list but it's 50x fater than python list. it was created in 2005 by developer called travis oliphant, it's deep down written in c++ language

# %%
#here we import numpy
import numpy as np

# %% [markdown]
# **her we do slicing and indexeing in numpy array**

# %%
ar1 = np.array([12,54,78,90,1])
print(ar1[1])
print(type(ar1))
print(ar1[-1])
print(ar1[1:4])
# Out:
# 54
# <class 'numpy.ndarray'>
# 1
# [54 78 90]

# %% [markdown]
# 1D Array

# %%
arr = np.array([11,22,33])
print(arr)
# Out:
# [11 22 33]

# %% [markdown]
# 2D array

# %%
arr2 = np.array([[22,32,43],[41,56,87],[44,5,7]])
# print(arr2[0][2])
# print(arr2[2][1])
# print(arr2.ndim)
print(arr2)
# Out:
# [[22 32 43]
#  [41 56 87]
#  [44  5  7]]

# %% [markdown]
# **Stastical operation**

# %%
arr9 = np.array([23,11,9,21,32,8,7])
# np.mean(arr9)  #average value
# np.sum(arr9)  #here it sum
# np.max(arr9)  #here we get maximum value
# np.min(arr9)  #here we get minimum value
# Out:
# np.int64(7)

# %% [markdown]
# **Mathematical operations**

# %%
a = np.array([21,11,4])
b = np.array([20,10,6])

# %%
np.add(a,b)
# Out:
# array([41, 21, 10])

# %%
np.subtract(a,b)
# Out:
# array([ 1,  1, -2])

# %%
np.multiply(a,b)
# Out:
# array([420, 110,  24])

# %%
np.divide(a,b)
# Out:
# array([1.05      , 1.1       , 0.66666667])
