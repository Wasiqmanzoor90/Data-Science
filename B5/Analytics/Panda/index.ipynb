# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.3 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd

# %% [markdown]
# **Pnadas was basically creted by developer namely wes mckey fot the manipulation or we can say for cleaning of data**

# %%
pl = [21,34,65,89]
print(pl)
# Out:
# [21, 34, 65, 89]

# %% [markdown]
# **Series convert data into 1D data**

# %%
ds = pd.Series(pl)
ds
# Out:
# 0    21
# 1    34
# 2    65
# 3    89
# dtype: int64

# %% [markdown]
# **DataFrame converts raw data into table format or we can say in 2D formt**

# %%
data={
    "Name":["Wasiq","Abdullah","Ali","Ahmed"],
    "Age":[21,34,65,89],
    "Adress":["New York","London","Paris","Berlin"]
}

# %%
data
# Out:
# {'Name': ['Wasiq', 'Abdullah', 'Ali', 'Ahmed'],
#  'Age': [21, 34, 65, 89],
#  'Adress': ['New York', 'London', 'Paris', 'Berlin']}

# %%
df = pd.DataFrame(data)
df
# Out:
#        Name  Age    Adress
# 0     Wasiq   21  New York
# 1  Abdullah   34    London
# 2       Ali   65     Paris
# 3     Ahmed   89    Berlin
