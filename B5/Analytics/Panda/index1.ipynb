# %%
import pandas as pd

# %%
data=pd.read_csv(r"C:\Users\Dell\Documents\Project\Dataset\netflix_titles.csv")

# %%
data.head()
# Out:
#     show_id     type                                    title  \
# 0  81145628    Movie  Norm of the North: King Sized Adventure
# 1  80117401    Movie               Jandino: Whatever it Takes
# 2  70234439  TV Show                       Transformers Prime
# 3  80058654  TV Show         Transformers: Robots in Disguise
# 4  80125979    Movie                             #realityhigh
#
#                    director  \
# 0  Richard Finn, Tim Maltby
# 1                       NaN
# 2                       NaN
# 3                       NaN
# 4          Fernando Lebrija
#
#                                                 cast  \
# 0  Alan Marriott, Andrew Toth, Brian Dobson, Cole...
# 1                                   Jandino Asporaat
# 2  Peter Cullen, Sumalee Montano, Frank Welker, J...
# 3  Will Friedle, Darren Criss, Constance Zimmer, ...
# 4  Nesta Cooper, Kate Walsh, John Michael Higgins...
#
#                                     country         date_added  release_year  \
# ...

# %%
data.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 6234 entries, 0 to 6233
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       6234 non-null   int64
#  1   type          6234 non-null   str
#  2   title         6234 non-null   str
#  3   director      4265 non-null   str
#  4   cast          5664 non-null   str
#  5   country       5758 non-null   str
#  6   date_added    6223 non-null   str
#  7   release_year  6234 non-null   int64
#  8   rating        6224 non-null   str
#  9   duration      6234 non-null   str
#  10  listed_in     6234 non-null   str
#  11  description   6234 non-null   str
# dtypes: int64(2), str(10)
# memory usage: 584.6 KB

# %%
data['type'].value_counts()
# Out:
# type
# Movie      4265
# TV Show    1969
# Name: count, dtype: int64

# %%
data.head()
# Out:
#     show_id     type                                    title  \
# 0  81145628    Movie  Norm of the North: King Sized Adventure
# 1  80117401    Movie               Jandino: Whatever it Takes
# 2  70234439  TV Show                       Transformers Prime
# 3  80058654  TV Show         Transformers: Robots in Disguise
# 4  80125979    Movie                             #realityhigh
#
#                    director  \
# 0  Richard Finn, Tim Maltby
# 1                       NaN
# 2                       NaN
# 3                       NaN
# 4          Fernando Lebrija
#
#                                                 cast  \
# 0  Alan Marriott, Andrew Toth, Brian Dobson, Cole...
# 1                                   Jandino Asporaat
# 2  Peter Cullen, Sumalee Montano, Frank Welker, J...
# 3  Will Friedle, Darren Criss, Constance Zimmer, ...
# 4  Nesta Cooper, Kate Walsh, John Michael Higgins...
#
#                                     country         date_added  release_year  \
# ...

# %%
data['release_year'].max()
# Out:
# np.int64(2020)

# %%
data['release_year'].min()
# Out:
# np.int64(1925)

# %%
data[data['release_year']==2020]
# Out:
#        show_id     type                                              title  \
# 1315  81034946  TV Show                                 Maradona in Mexico
# 3180  81214114    Movie                                      Bulletproof 2
# 3189  81039393  TV Show                                              Cheer
# 3195  80233408    Movie                              Live Twice, Love Once
# 3220  80997687  TV Show                                            Dracula
# 3221  80237347  TV Show                                Go! Go! Cory Carson
# 3249  81006825    Movie                      All the Freckles in the World
# 3325  81160763  TV Show                                     Sex, Explained
# 3352  81127902    Movie                                  A Fall from Grace
# 3353  80995039  TV Show                                               Ares
# 3354  81062580  TV Show                                 Nailed It! Germany
# ...

# %%
data[data['release_year']==1925]
# Out:
#        show_id     type                              title director cast  \
# 4292  81030762  TV Show  Pioneers: First Women Filmmakers*      NaN  NaN
#
#      country         date_added  release_year rating  duration listed_in  \
# 4292     NaN  December 30, 2018          1925  TV-PG  1 Season  TV Shows
#
#                                             description
# 4292  This collection restores films from women who ...

# %%
data['director'].isnull().sum()
# Out:
# np.int64(1969)

# %%
data[data['cast'].str.contains("Shah Rukh Khan")]
# Out:
#        show_id   type                                              title  \
# 533   81121023  Movie  My Next Guest with David Letterman and Shah Ru...
# 1649  80164778  Movie                                              Raees
# 1686  81005364  Movie                                               Zero
# 1761  80157133  Movie                                          Chamatkar
# 1764  80157083  Movie                               Kabhi Haan Kabhi Naa
# 1767  24081514  Movie                                          Ram Jaane
# 1884  80158395  Movie                                            Chaahat
# 1890  20764666  Movie                              English Babu Desi Mem
# 2216  60021758  Movie                                              Asoka
# 2221  80156935  Movie                                         One 2 Ka 4
# 2335  17671454  Movie                                             Dil Se
# 2363  80059049  Movie                                             Pardes
# ...

# %%
data[data['cast'].str.contains("Salman Khan")]
# Out:
#        show_id   type                                     title  \
# 576   70198040  Movie                                     Ready
# 1301  70040076  Movie                   Lucky: No Time for Love
# 1306  70260514  Movie                           Mumbai Cha Raja
# 1737  20258084  Movie                           Andaz Apna Apna
# 2362  80223230  Movie                                  No Entry
# 3657  60035870  Movie                       Hum Aapke Hain Koun
# 3658  80074065  Movie                      Hum Saath-Saath Hain
# 3665  19207412  Movie                           Maine Pyar Kiya
# 4186  81213893  Movie                            Chal Mere Bhai
# 4202  81213885  Movie  Jaan-E-Mann: Let's Fall in Love... Again
# 4206  17457622  Movie                                    Judwaa
# 4212  70040912  Movie                     Maine Pyaar Kyun Kiya
# 4214  70018445  Movie                      Mujhse Shaadi Karogi
# 4921  70114589  Movie                     Main aurr Mrs. Khanna
#
# ...

# %%
data[data['director'].str.contains("Christopher Nolan")]
# Out:
#        show_id   type      title           director  \
# 3524  70131314  Movie  Inception  Christopher Nolan
#
#                                                    cast  \
# 3524  Leonardo DiCaprio, Joseph Gordon-Levitt, Ellen...
#
#                             country       date_added  release_year rating  \
# 3524  United States, United Kingdom  January 1, 2020          2010  PG-13
#
#      duration                                        listed_in  \
# 3524  148 min  Action & Adventure, Sci-Fi & Fantasy, Thrillers
#
#                                             description
# 3524  In this mind-bending sci-fi thriller, a man ru...

# %%
data[data['director'].str.contains("James Cameron")]
# Out:
# Empty DataFrame
# Columns: [show_id, type, title, director, cast, country, date_added, release_year, rating, duration, listed_in, description]
# Index: []

# %%
data['country'].value_counts()
# Out:
# country
# United States                              2032
# India                                       777
# United Kingdom                              348
# Japan                                       176
# Canada                                      141
#                                            ...
# United States, Hungary, Ireland, Canada       1
# Norway, Sweden                                1
# United States, Mexico, Colombia               1
# Italy, Germany                                1
# Cyprus, Austria, Thailand                     1
# Name: count, Length: 554, dtype: int64

# %%
data.shape
# Out:
# (6234, 12)

# %%
data['country'].isnull().sum()
# Out:
# np.int64(0)

# %%
data['country']= data['country'].fillna('Unknown')

# %%
data['country'].value_counts()
# Out:
# country
# United States                              2032
# India                                       777
# Unknown                                     476
# United Kingdom                              348
# Japan                                       176
#                                            ...
# United States, Hungary, Ireland, Canada       1
# Norway, Sweden                                1
# United States, Mexico, Colombia               1
# Italy, Germany                                1
# Cyprus, Austria, Thailand                     1
# Name: count, Length: 555, dtype: int64

# %%
data.head(1)
# Out:
#     show_id   type                                    title  \
# 0  81145628  Movie  Norm of the North: King Sized Adventure
#
#                    director  \
# 0  Richard Finn, Tim Maltby
#
#                                                 cast  \
# 0  Alan Marriott, Andrew Toth, Brian Dobson, Cole...
#
#                                     country         date_added  release_year  \
# 0  United States, India, South Korea, China  September 9, 2019          2019
#
#   rating duration                           listed_in  \
# 0  TV-PG   90 min  Children & Family Movies, Comedies
#
#                                          description
# 0  Before planning an awesome wedding for his gra...
