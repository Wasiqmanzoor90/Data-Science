# %% [markdown]
# Numerical Python is a Python libarary which is also known as numpy, its basically 50x faster than normal python list. it was created in 2005 by developer named travis oliphant, it get widely used due its speed
# and consistency data

# %%
#here we install numpy
# !pip install numpy
# Out:
# ...
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import numpy as np

# %%
arr = np.array([12,89,67,90,11])
print(arr[1:4])
print(arr[-2])
# Out:
# [89 67 90]
# 90

# %% [markdown]
# To know the total number of dimesion of numpy array

# %%
ar1 = np.array([21,54,89,93,59,90])
print(ar1[1:])
print(ar1.ndim)
# Out:
# [54 89 93 59 90]
# 1
