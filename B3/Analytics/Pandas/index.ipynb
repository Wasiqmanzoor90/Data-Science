# %%
pip install pandas

# %%
import pandas as pd

# %% [markdown]
# **wes mckery was the founder of pandas he created it for it for doing manpulation of data or we can say for cleaning of data so in pandas here are two types of data structure**

# %% [markdown]
# **Series deals with 1D and Dataframe deals with 2D or we can say rows and columns**

# %%
dt = [21,45,78,90]
dp = pd.Series(dt)
print(dp)
# Out:
# 0    21
# 1    45
# 2    78
# 3    90
# dtype: int64

# %%
dtr = {
    "name":['wasiq','umer','ubaid'],
    "age":[26,21,29],
    "adress":['sgr',"blr",'LA']
}

# %% [markdown]
# Here Dataframe mean 2d

# %%
df = pd.DataFrame(dtr)
print(df)
# Out:
#     name  age adress
# 0  wasiq   26    sgr
# 1   umer   21    blr
# 2  ubaid   29     LA

# %%
data = pd.read_csv('titanic.csv')

# %%
data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
data = pd.read_csv(r"C:\Users\Dell\Documents\Project\Dataset\titanic.csv")

# %% [markdown]
# **Head gives first 5 rows by default**

# %%
data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# **Here tail give last 5 rows by default**

# %%
data.tail()
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %% [markdown]
# **Shape tells us how row and columns are there in total**

# %%
data.shape
# Out:
# (891, 12)

# %%
data.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    str
#  4   Sex          891 non-null    str
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    str
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    str
#  11  Embarked     889 non-null    str
# dtypes: float64(2), int64(5), str(5)
# memory usage: 83.7 KB

# %% [markdown]
# **Here isnull how many null value are there in dataset and sum function adds all the null valie in a particular column**

# %%
data.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %% [markdown]
# **Here not null means how many not null value present in a dataset**

# %%
data.notnull().sum()
# Out:
# PassengerId    891
# Survived       891
# Pclass         891
# Name           891
# Sex            891
# Age            714
# SibSp          891
# Parch          891
# Ticket         891
# Fare           891
# Cabin          204
# Embarked       889
# dtype: int64

# %%
data.head(7)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# 6                            McCarthy, Mr. Timothy J    male  54.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# ...

# %%
d1 = data[['Name','Age','Sex']]

# %%
d1
# Out:
#                                                   Name   Age     Sex
# 0                              Braund, Mr. Owen Harris  22.0    male
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0  female
# 2                               Heikkinen, Miss. Laina  26.0  female
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0  female
# 4                             Allen, Mr. William Henry  35.0    male
# ..                                                 ...   ...     ...
# 886                              Montvila, Rev. Juozas  27.0    male
# 887                       Graham, Miss. Margaret Edith  19.0  female
# 888           Johnston, Miss. Catherine Helen "Carrie"   NaN  female
# 889                              Behr, Mr. Karl Howell  26.0    male
# 890                                Dooley, Mr. Patrick  32.0    male
#
# [891 rows x 3 columns]

# %%
data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# **Loc deals with names**

# %%
data.loc[0,'Ticket']
# Out:
# 'A/5 21171'

# %% [markdown]
# **Iloc fully deals with numbers**

# %%
data.loc[:,'Name']
# Out:
# 0                                Braund, Mr. Owen Harris
# 1      Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                                 Heikkinen, Miss. Laina
# 3           Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                               Allen, Mr. William Henry
#                              ...
# 886                                Montvila, Rev. Juozas
# 887                         Graham, Miss. Margaret Edith
# 888             Johnston, Miss. Catherine Helen "Carrie"
# 889                                Behr, Mr. Karl Howell
# 890                                  Dooley, Mr. Patrick
# Name: Name, Length: 891, dtype: str

# %%
data.iloc[0,3]
# Out:
# 'Braund, Mr. Owen Harris'

# %%
data.iloc[3,10]
# Out:
# 'C123'

# %%
data.iloc[1,10]
# Out:
# 'C85'

# %%
data.iloc[3,8]
# Out:
# '113803'

# %%
data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
data.sort_values(by='Fare')
# Out:
#      PassengerId  Survived  Pclass                                Name  \
# 815          816         0       1                    Fry, Mr. Richard
# 806          807         0       1              Andrews, Mr. Thomas Jr
# 413          414         0       2      Cunningham, Mr. Alfred Fleming
# 481          482         0       2    Frost, Mr. Anthony Wood "Archie"
# 302          303         0       3     Johnson, Mr. William Cahoone Jr
# ..           ...       ...     ...                                 ...
# 438          439         0       1                   Fortune, Mr. Mark
# 341          342         1       1      Fortune, Miss. Alice Elizabeth
# 737          738         1       1              Lesurer, Mr. Gustave J
# 679          680         1       1  Cardeza, Mr. Thomas Drake Martinez
# 258          259         1       1                    Ward, Miss. Anna
#
#         Sex   Age  SibSp  Parch    Ticket      Fare        Cabin Embarked
# ...

# %%
data.sort_values(by='Fare',ascending=False)
# Out:
#      PassengerId  Survived  Pclass                                Name  \
# 679          680         1       1  Cardeza, Mr. Thomas Drake Martinez
# 258          259         1       1                    Ward, Miss. Anna
# 737          738         1       1              Lesurer, Mr. Gustave J
# 88            89         1       1          Fortune, Miss. Mabel Helen
# 438          439         0       1                   Fortune, Mr. Mark
# ..           ...       ...     ...                                 ...
# 806          807         0       1              Andrews, Mr. Thomas Jr
# 815          816         0       1                    Fry, Mr. Richard
# 466          467         0       2               Campbell, Mr. William
# 481          482         0       2    Frost, Mr. Anthony Wood "Archie"
# 822          823         0       1     Reuchlin, Jonkheer. John George
#
#         Sex   Age  SibSp  Parch    Ticket      Fare        Cabin Embarked
# ...

# %%
data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# **Here value counts mainly get used by categorical data it gives total number of sum**

# %%
data['Sex'].value_counts()
# Out:
# Sex
# male      577
# female    314
# Name: count, dtype: int64

# %%
data['Pclass'].value_counts()
# Out:
# Pclass
# 3    491
# 1    216
# 2    184
# Name: count, dtype: int64

# %%
data['Survived'].value_counts()
# Out:
# Survived
# 0    549
# 1    342
# Name: count, dtype: int64

# %% [markdown]
# Here we are changing value of survived column from 0 and 1 to alive and dead

# %%
data['Survived']= data['Survived'].map({0:'Alive',1:"Dead"})

# %%
data.head()
# Out:
#    PassengerId Survived  Pclass  \
# 0            1    Alive       3
# 1            2     Dead       1
# 2            3     Dead       3
# 3            4     Dead       1
# 4            5    Alive       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
data['Survived'].value_counts()
# Out:
# Survived
# Alive    549
# Dead     342
# Name: count, dtype: int64

# %%
data.sort_values(by='Age')
# Out:
#      PassengerId Survived  Pclass                                      Name  \
# 803          804     Dead       3           Thomas, Master. Assad Alexander
# 755          756     Dead       2                 Hamalainen, Master. Viljo
# 644          645     Dead       3                    Baclini, Miss. Eugenie
# 469          470     Dead       3             Baclini, Miss. Helene Barbara
# 78            79     Dead       2             Caldwell, Master. Alden Gates
# ..           ...      ...     ...                                       ...
# 859          860    Alive       3                          Razi, Mr. Raihed
# 863          864    Alive       3         Sage, Miss. Dorothy Edith "Dolly"
# 868          869    Alive       3               van Melkebeke, Mr. Philemon
# 878          879    Alive       3                        Laleff, Mr. Kristo
# 888          889    Alive       3  Johnston, Miss. Catherine Helen "Carrie"
#
# ...

# %%
data['Age'].isnull().sum()
# Out:
# np.int64(177)

# %% [markdown]
# Here we get maximum number of age

# %%
data['Age'].max()
# Out:
# np.float64(80.0)

# %% [markdown]
# Here we get youngest age

# %%
data['Age'].min()
# Out:
# np.float64(0.42)

# %% [markdown]
# Here we get average age that are on titanic

# %%
data['Age'].mean()
# Out:
# np.float64(29.69911764705882)

# %% [markdown]
# Here we only alive people

# %%
d1 = data[data['Survived']=='Alive']

# %%
d1.head()
# Out:
#    PassengerId Survived  Pclass                            Name   Sex   Age  \
# 0            1    Alive       3         Braund, Mr. Owen Harris  male  22.0
# 4            5    Alive       3        Allen, Mr. William Henry  male  35.0
# 5            6    Alive       3                Moran, Mr. James  male   NaN
# 6            7    Alive       1         McCarthy, Mr. Timothy J  male  54.0
# 7            8    Alive       3  Palsson, Master. Gosta Leonard  male   2.0
#
#    SibSp  Parch     Ticket     Fare Cabin Embarked
# 0      1      0  A/5 21171   7.2500   NaN        S
# 4      0      0     373450   8.0500   NaN        S
# 5      0      0     330877   8.4583   NaN        Q
# 6      0      0      17463  51.8625   E46        S
# 7      3      1     349909  21.0750   NaN        S

# %% [markdown]
# Here we get only data that have less 18 age

# %%
data[data['Age']<18]

# %%
data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
data.sort_values(by='Fare', ascending=False)
# Out:
#      PassengerId  Survived  Pclass                                Name  \
# 679          680         1       1  Cardeza, Mr. Thomas Drake Martinez
# 258          259         1       1                    Ward, Miss. Anna
# 737          738         1       1              Lesurer, Mr. Gustave J
# 88            89         1       1          Fortune, Miss. Mabel Helen
# 438          439         0       1                   Fortune, Mr. Mark
# ..           ...       ...     ...                                 ...
# 806          807         0       1              Andrews, Mr. Thomas Jr
# 815          816         0       1                    Fry, Mr. Richard
# 466          467         0       2               Campbell, Mr. William
# 481          482         0       2    Frost, Mr. Anthony Wood "Archie"
# 822          823         0       1     Reuchlin, Jonkheer. John George
#
#         Sex   Age  SibSp  Parch    Ticket      Fare        Cabin Embarked
# ...

# %%
d2 = data[data['Survived']=='Alive']

# %%
d2
# Out:
#      PassengerId Survived  Pclass                                      Name  \
# 0              1    Alive       3                   Braund, Mr. Owen Harris
# 4              5    Alive       3                  Allen, Mr. William Henry
# 5              6    Alive       3                          Moran, Mr. James
# 6              7    Alive       1                   McCarthy, Mr. Timothy J
# 7              8    Alive       3            Palsson, Master. Gosta Leonard
# ..           ...      ...     ...                                       ...
# 884          885    Alive       3                    Sutehall, Mr. Henry Jr
# 885          886    Alive       3      Rice, Mrs. William (Margaret Norton)
# 886          887    Alive       2                     Montvila, Rev. Juozas
# 888          889    Alive       3  Johnston, Miss. Catherine Helen "Carrie"
# 890          891    Alive       3                       Dooley, Mr. Patrick
#
# ...

# %%
data[data['Survived'].isin(["Alive"])]
# Out:
#      PassengerId Survived  Pclass                                      Name  \
# 0              1    Alive       3                   Braund, Mr. Owen Harris
# 4              5    Alive       3                  Allen, Mr. William Henry
# 5              6    Alive       3                          Moran, Mr. James
# 6              7    Alive       1                   McCarthy, Mr. Timothy J
# 7              8    Alive       3            Palsson, Master. Gosta Leonard
# ..           ...      ...     ...                                       ...
# 884          885    Alive       3                    Sutehall, Mr. Henry Jr
# 885          886    Alive       3      Rice, Mrs. William (Margaret Norton)
# 886          887    Alive       2                     Montvila, Rev. Juozas
# 888          889    Alive       3  Johnston, Miss. Catherine Helen "Carrie"
# 890          891    Alive       3                       Dooley, Mr. Patrick
#
# ...

# %% [markdown]
# Here we are filtering titanic dataset on the basis of age and survived

# %%
data[
    (data['Survived']=='Alive')&
    (data['Age']<18)
]
# Out:
#      PassengerId Survived  Pclass                                     Name  \
# 7              8    Alive       3           Palsson, Master. Gosta Leonard
# 14            15    Alive       3     Vestrom, Miss. Hulda Amanda Adolfina
# 16            17    Alive       3                     Rice, Master. Eugene
# 24            25    Alive       3            Palsson, Miss. Torborg Danira
# 50            51    Alive       3               Panula, Master. Juha Niilo
# 59            60    Alive       3       Goodwin, Master. William Frederick
# 63            64    Alive       3                    Skoog, Master. Harald
# 71            72    Alive       3               Goodwin, Miss. Lillian Amy
# 86            87    Alive       3                   Ford, Mr. William Neal
# 111          112    Alive       3                     Zabour, Miss. Hileni
# 114          115    Alive       3                    Attalah, Miss. Malake
# ...

# %%
data[
    (data['Survived']=='Alive')&
    (data['Age']<18)&
    (data['Sex']=='male')
]
# Out:
#      PassengerId Survived  Pclass                                     Name  \
# 7              8    Alive       3           Palsson, Master. Gosta Leonard
# 16            17    Alive       3                     Rice, Master. Eugene
# 50            51    Alive       3               Panula, Master. Juha Niilo
# 59            60    Alive       3       Goodwin, Master. William Frederick
# 63            64    Alive       3                    Skoog, Master. Harald
# 86            87    Alive       3                   Ford, Mr. William Neal
# 138          139    Alive       3                      Osen, Mr. Olaf Elon
# 163          164    Alive       3                          Calic, Mr. Jovo
# 164          165    Alive       3             Panula, Master. Eino Viljami
# 171          172    Alive       3                     Rice, Master. Arthur
# 182          183    Alive       3    Asplund, Master. Clarence Gustaf Hugo
# ...

# %%
data[
    (data['Age']>70)&
    (data['Pclass']==1)
]
# Out:
#      PassengerId Survived  Pclass                                  Name   Sex  \
# 96            97    Alive       1             Goldschmidt, Mr. George B  male
# 493          494    Alive       1               Artagaveytia, Mr. Ramon  male
# 630          631     Dead       1  Barkworth, Mr. Algernon Henry Wilson  male
#
#       Age  SibSp  Parch    Ticket     Fare Cabin Embarked
# 96   71.0      0      0  PC 17754  34.6542    A5        C
# 493  71.0      0      0  PC 17609  49.5042   NaN        C
# 630  80.0      0      0     27042  30.0000   A23        S

# %%
data.head()
# Out:
#    PassengerId Survived  Pclass  \
# 0            1    Alive       3
# 1            2     Dead       1
# 2            3     Dead       3
# 3            4     Dead       1
# 4            5    Alive       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
data[data['Name'].str.contains('Braund')]
# Out:
#      PassengerId Survived  Pclass                       Name   Sex   Age  \
# 0              1    Alive       3    Braund, Mr. Owen Harris  male  22.0
# 477          478    Alive       3  Braund, Mr. Lewis Richard  male  29.0
#
#      SibSp  Parch     Ticket    Fare Cabin Embarked
# 0        1      0  A/5 21171  7.2500   NaN        S
# 477      1      0       3460  7.0458   NaN        S

# %%
data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                                       Jasira Fayaz    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# When we update the particular value

# %%
data.loc[0,'Name'] = 'Jasira Fayaz'

# %%
data.iloc[1,3]
# Out:
# 'Cumings, Mrs. John Bradley (Florence Briggs Thayer)'

# %% [markdown]
# When we want change data with value

# %%
data.replace('Cumings, Mrs. John Bradley (Florence Briggs Thayer)','Wasiq Manzoor',inplace=True)
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                                    Jasira Fayaz    male  22.0      1      0
# 1                                   Wasiq Manzoor  female  38.0      1      0
# 2                          Heikkinen, Miss. Laina  female  26.0      0      0
# 3    Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1      0
# 4                        Allen, Mr. William Henry    male  35.0      0      0
# ...

# %% [markdown]
# when we want to set pssengerid as index column

# %%
data.set_index('PassengerId',inplace=True)

# %%
data.head()
# Out:
#             Survived  Pclass  \
# PassengerId
# 1              Alive       3
# 2               Dead       1
# 3               Dead       3
# 4               Dead       1
# 5              Alive       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
#
#              SibSp  Parch            Ticket     Fare Cabin Embarked
# PassengerId
# 1                1      0         A/5 21171   7.2500   NaN        S
# 2                1      0          PC 17599  71.2833   C85        C
# 3                0      0  STON/O2. 3101282   7.9250   NaN        S
# ...

# %%
data.iloc[1,2]
# Out:
# 'Cumings, Mrs. John Bradley (Florence Briggs Thayer)'

# %% [markdown]
# when we want to change column name

# %%
data.rename(columns={'Sex': 'Gender'}, inplace=True)

# %%
data.head()
# Out:
#             Survived  Pclass  \
# PassengerId
# 1              Alive       3
# 2               Dead       1
# 3               Dead       3
# 4               Dead       1
# 5              Alive       3
#
#                                                           Name  Gender   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
#
#              SibSp  Parch            Ticket     Fare Cabin Embarked
# PassengerId
# 1                1      0         A/5 21171   7.2500   NaN        S
# 2                1      0          PC 17599  71.2833   C85        C
# 3                0      0  STON/O2. 3101282   7.9250   NaN        S
# ...

# %% [markdown]
# **group by mean simply split data in groups**

# %%
data.groupby('Sex')['Survived'].sum()
# Out:
# Sex
# female    233
# male      109
# Name: Survived, dtype: int64

# %%
data.groupby('Sex')['Survived'].mean()
# Out:
# Sex
# female    0.742038
# male      0.188908
# Name: Survived, dtype: float64

# %%
data.groupby('Pclass')['Survived'].sum()
# Out:
# Pclass
# 1    136
# 2     87
# 3    119
# Name: Survived, dtype: int64

# %%
data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
data.groupby('Pclass')['Fare'].sum()
# Out:
# Pclass
# 1    18177.4125
# 2     3801.8417
# 3     6714.6951
# Name: Fare, dtype: float64

# %%
data.groupby('Age')['Survived'].sum()
# Out:
# Age
# 0.42     1
# 0.67     1
# 0.75     2
# 0.83     2
# 0.92     1
#         ..
# 70.00    0
# 70.50    0
# 71.00    0
# 74.00    0
# 80.00    1
# Name: Survived, Length: 88, dtype: int64

# %%
children = data[data['Age']<10]

# %%
children.shape
# Out:
# (62, 12)

# %%
# rename value  0 to alive and 1 to dead
children['Survived']= children['Survived'].map({0:'Alive',1:"Dead"})

# %%
children.groupby('Age')['Survived'].sum()
# Out:
# Age
# 0.42                                               Dead
# 0.67                                               Dead
# 0.75                                           DeadDead
# 0.83                                           DeadDead
# 0.92                                               Dead
# 1.00                     AliveDeadDeadDeadAliveDeadDead
# 2.00    AliveAliveAliveAliveAliveDeadDeadDeadAliveAlive
# 3.00                          DeadDeadDeadDeadAliveDead
# 4.00        DeadAliveAliveDeadDeadDeadDeadDeadAliveDead
# 5.00                                   DeadDeadDeadDead
# 6.00                                      DeadDeadAlive
# 7.00                                     AliveAliveDead
# 8.00                                 AliveDeadDeadAlive
# 9.00             AliveDeadAliveAliveDeadAliveAliveAlive
# Name: Survived, dtype: str
