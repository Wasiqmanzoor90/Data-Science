# %% [markdown]
# **Numerical Python which is also known as Numpy. it have a concept called numpy array which is basically 50X faster than traditional python list. It was created in 2005 by a developer called travis oliphant, it's is widely for the speed and data consistency**

# %%
pip install numpy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np

# %%
arr = np.array([21,45,90,'wasiq'])
print(arr)
# Out:
# ['21' '45' '90' 'wasiq']

# %%
ar1 = np.array([21,45,90])
print(ar1.ndim)
# Out:
# 1

# %%
ar3 = np.array([[21,34,45],[11,76,10],[11,76,10]])
print(ar3)
# Out:
# [[21 34 45]
#  [11 76 10]
#  [11 76 10]]

# %%
ar3 = np.array([1, 2, 3,21,34,45,11,76,10,11,76,10])
# print(ar3[3:7])
# print(ar3[3:])
print(ar3[0:12:2])
print(ar3[::-2])
# Out:
# [ 1  3 34 11 10 76]
# [10 11 76 45 21  2]

# %%
ar3 = np.array([[21,34,45],[11,76,10],[11,76,10]])
# print(ar3)
print(ar3[1][0])
# Out:
# 11

# %% [markdown]
# **Stastical operation**

# %%
ar3 = np.array([1, 2, 3,21,34,45,11,76,10,11,76,10])
np.max(ar3)  #maximum value
np.mean(ar3)  #average value
np.min(ar3)  #minimum value
np.sum(ar3)  #sum of all item
np.median(ar3)  #middle value
# Out:
# np.float64(1.1)

# %% [markdown]
# **Mathamaitical operation**

# %%
ar1 = np.array([2,4,6])
ar2 = np.array([8,9,10])
np.add(ar1,ar2)
# Out:
# array([10, 13, 16])

# %%
np.subtract(ar1,ar2)
# Out:
# array([-6, -5, -4])

# %%
np.multiply(ar1,ar2)
# Out:
# array([16, 36, 60])

# %%
np.divide(ar1,ar2)
# Out:
# array([0.25      , 0.44444444, 0.6       ])

# %%
x = np.random.rand()  #rand gives by default number between 0 to 1
print(x)
# Out:
# 0.5391759880733366

# %%
x = np.random.rand(5)   
print(x)
# Out:
# [0.48343669 0.61876236 0.54977392 0.5119682  0.37951066]

# %%
y = np.random.randint(1,10)
print(y)
# Out:
# 9

# %%
z = np.random.randint(1000,9999,size=3)
print(z)
# Out:
# [7802 1741 4106]

# %%
z1 = np.random.randint(100000, 999999)
print(z1)
# Out:
# 701496

# %%
z2 = np.random.randn()
print(z2)
# Out:
# 0.6473581370862865

# %%
a1 = np.array([21,56,90,10,34,29])
new_arry = a1.reshape(3,2)
print(new_arry)
# Out:
# [[21 56]
#  [90 10]
#  [34 29]]

# %%
a1 = np.array([2,4,6,8])

# %%
np.power(a1,3)
# Out:
# array([ 4, 16, 36, 64])

# %%
np.sqrt(a1)
# Out:
# array([1.41421356, 2.        , 2.44948974, 2.82842712])
